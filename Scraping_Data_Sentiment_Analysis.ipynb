# %% [markdown]
# <a href="https://colab.research.google.com/github/Differentlv/Sentiment-analysis-of-youtube-app-reviews-on-playstore-using-machine-learning/blob/main/Scraping_Data_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Library Installation

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# 2. Importing Library

# %%
from google_play_scraper import Sort, reviews_all
import csv
import pandas as pd

# %% [markdown]
# 3. Scrapping Details

# %%
#Mengambil ulasan dari site
scrapreview = reviews_all(
    'com.google.android.youtube',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=150000
)

scrapreview_limited = scrapreview[:150000]

# %% [markdown]
# 4. Output Details

# %%
dataView = pd.DataFrame(scrapreview_limited)
dataView.head()
# Out:
#                                reviewId         userName  \
# 0  2c298fbb-225e-402b-890d-bc52031f2223  Pengguna Google
# 1  1ad6670e-acbf-4273-a60a-563ba45b4046  Pengguna Google
# 2  cac87529-53a3-4f14-b4ed-2e441aea8813  Pengguna Google
# 3  63513916-37fa-40d2-ab72-84b3086dbc8f  Pengguna Google
# 4  4108ed07-ad5a-4de2-8bb7-d8c23d8ce08c  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Sangat bagus, jelas lah. Tapi audio trek yang ...      3             12
# 1  update an terbaru youtube ini agak mengganggu,...      2            141
# 2  Asli nya semua perfect jadi aku kasi bintang 1...      1             57
# 3  patch update terbaru sepertinya banyak bug yan...      2              4
# 4  setelah update semakin buruk. fitur trek audio...      1              4
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0             20.03.37 2025-06-22 13:15:06         None      None   20.03.37
# 1             20.23.37 2025-06-18 15:23:12         None      None   20.23.37
# 2             20.24.39 2025-06-24 12:12:55         None      None   20.24.39
# 3             20.24.39 2025-06-22 17:36:16         None      None   20.24.39
# 4             20.24.39 2025-06-24 12:15:13         None      None   20.24.39

# %%
with open('hasil_scraping_youtube.csv', mode='w', newline='', encoding='utf-8') as file:
      writer = csv.writer(file)

      writer.writerow(['content','score'])


      for review in scrapreview_limited:
          writer.writerow([
              review['content'],
              review.get('score', '')
          ])

print("Data telah disimpan ke hasil_scraping_youtube.csv")
# Out:
# Data telah disimpan ke hasil_scraping_youtube.csv
